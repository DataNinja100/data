# %% [markdown]
# load data and setup

# %%
from pymongo import MongoClient
import pandas as pd

# read only
connection_string = "mongodb+srv://thomas:4c84qHaDIZWgpMf3@cluster0.xa1cxxl.mongodb.net/APP"

# Connect to MongoDB
client = MongoClient(connection_string)

# Access database
db = client['APP']

collection = db['stocks']

df = pd.DataFrame(list(collection.find({}, {'_id': 0})))
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# Earnings data

# %%
earnings_df=df[df['info'].str.startswith('e{')]

# %%
earnings_df
# Out:
#        Stock                            Rank                  EPS Percentage  \
# 88      ccep                           2-Buy                               0
# 89        kt                          4-Sell                               0
# 90      sbsw  There is no info on this stock  There is no info on this stock
# 91      cmcm  There is no info on this stock  There is no info on this stock
# 92       abm                           2-Buy                               0
# ...      ...                             ...                             ...
# 117119  smsi                          3-Hold                               0
# 117120   cyn  There is no info on this stock  There is no info on this stock
# 117121  clrb                          4-Sell                               0
# 117122  hyfm  There is no info on this stock  There is no info on this stock
# 117123  auud  There is no info on this stock  There is no info on this stock
#
# ...

# %% [markdown]
# past earnings example ie stock has already posted earnings, and we track result: symbol, name, epsForecast(what they were expected to have), eps(actual eps), noof ests (number of estimates), market cap, surprise (surprise percentage of earnings), is past earnings: true if earnings has passed, false otherwise, correct date: date of actual earnings

# %%
earnings_df.iloc[-1]['info']
# Out:
# 'e{"symbol":"AUUD","name":"Auddia Inc.","epsForecast":"N/A","eps":"$14.97","noOfEsts":"1","marketCap":"$2,291,331","surprise":"N/A","isPastEarnings":true,"correct_date":"2026-03-04"}'

# %% [markdown]
# example of future earnings example, now u have time (before market, after or unknown, last year eps) and is past earnings false.

# %%
earnings_df.iloc[0]['info']
# Out:
# 'e{"symbol":"CCEP","name":"Coca-Cola Europacific Partners plc","time":"N/A","lastYearEPS":"N/A","epsForecast":"N/A","noOfEsts":"4","marketCap":"$42,048,841,553","isPastEarnings":false}'

# %% [markdown]
# Et is where people just check earnings time (date and time). Timestamp is when they did it (as it is in all dfs)

# %%
earnings_time_df=df[df['info'].str.startswith('et')]

# %%
earnings_time_df
# Out:
#        Stock                            Rank                  EPS Percentage  \
# 0       ggrg  There is no info on this stock  There is no info on this stock
# 1        eix                          3-Hold                           -6.64
# 2       urng  There is no info on this stock  There is no info on this stock
# 3        etd                          3-Hold                               0
# 4        rnw                           2-Buy                               0
# ...      ...                             ...                             ...
# 117176   bah                          3-Hold                           -1.94
# 117177  phsp  There is no info on this stock  There is no info on this stock
# 117178   niq                           2-Buy                           17.18
# 117179   mdb                          3-Hold                           -0.15
# 117180  expi                          3-Hold                               0
#
# ...

# %% [markdown]
# My monthly yt videos are based on this, every month for over 6k stocks, record rank and price when looked up (last price), info contains 52 week high and low

# %%
earnings_price_df=df[df['info'].str.startswith('el')]

# %%
earnings_price_df
# Out:
#         Stock    Rank EPS Percentage Growth Last_Price     Date     Time  \
# 3128        v       3           -3.4   13.1     349.82  7/22/25  Unknown
# 3129      val  5-Sell            0.0      0      46.01  7/30/25  Unknown
# 3130     vale       3            0.0  17.51        9.4  7/24/25  Unknown
# 3131     vbnk  5-Sell            0.0      0      11.01   9/4/25  Unknown
# 3132     vbtx       3            0.0      0       24.5  7/22/25  Unknown
# ...       ...     ...            ...    ...        ...      ...      ...
# 107534   azta       4            0.0      0      28.62   5/6/26  Unknown
# 107535   abnb       2           9.89  13.68     121.35   5/7/26  Unknown
# 107536  alsmy       3              0      0       3.37       NA  Unknown
# 107537   amat       2          15.28   11.7     354.91  5/21/26  Unknown
# 107538  asccy       5              0      0      29.08  2/13/26  Unknown
#
#                                  info               timestamp  \
# ...

# %% [markdown]
# This one is for people checking the zachs rank only for their stocks at time timestamp

# %%
portfolio_df=df[df['info'].str.startswith('p')]

# %%
portfolio_df
# Out:
#        Stock                            Rank                  EPS Percentage  \
# 44      ggrg  There is no info on this stock  There is no info on this stock
# 45       eix                          3-Hold                           -6.64
# 46      urng  There is no info on this stock  There is no info on this stock
# 47       etd                          3-Hold                               0
# 48       rnw                           2-Buy                               0
# ...      ...                             ...                             ...
# 117233   bah                          3-Hold                           -1.94
# 117234  phsp  There is no info on this stock  There is no info on this stock
# 117235   niq                           2-Buy                           17.18
# 117236   mdb                          3-Hold                           -0.15
# 117237  expi                          3-Hold                               0
#
# ...

# %% [markdown]
# Dividend df

# %%
dividends_df=df[df['info'].str.startswith('d')]

# %%
dividends_df
# Out:
#        Stock                            Rank                  EPS Percentage  \
# 111     amkr                   5-Strong Sell                               0
# 112     gogl                   5-Strong Sell                               0
# 113      hwc                          3-Hold                               0
# 114     lstr                          4-Sell                               0
# 115     nrim                    1-Strong Buy                               0
# ...      ...                             ...                             ...
# 117008  sbgi                           2-Buy                               0
# 117009  tcbs  There is no info on this stock  There is no info on this stock
# 117010  umbf                    1-Strong Buy                           -2.57
# 117011  ubcp  There is no info on this stock  There is no info on this stock
# 117012  vctr                          3-Hold                               0
#
# ...

# %% [markdown]
# Early entries have name, time (which is payment date), dic yield(in percentage for annualised div), and div amount for the ex date

# %%
dividends_df.iloc[0]['info']
# Out:
# 'd{"Info":"Amkor Technology, Inc. Common Stock","Time":"6/25/2025","Yield":1.83,"Dividend_Amount":0.08269}'

# %% [markdown]
# Newer entries add ex date

# %%
dividends_df.iloc[-1]['info']
# Out:
# 'd{"Info":"Victory Capital Holdings, Inc. Class A Common Stock","Time":"3/25/2026","Yield":2.76,"Dividend_Amount":0.49,"Ex_Date":"2026-03-10"}'
